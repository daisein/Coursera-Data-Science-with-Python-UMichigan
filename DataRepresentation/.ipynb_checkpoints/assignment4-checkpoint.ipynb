# %% [markdown]
# # Real Estate Analytics

# %% [raw]
# Question: does Hong Kong have a "Real estate bubble"?
#
# Game plan:
# Comparing Hong Kong's current real estate price to US post 2008 market crash, on four metrics:
#
#     1. House Price-Rent Ratio (input: price, rent)
#     2. House Price-Income Ratio (input: price, income)
#     3. Credit to Households (% of GDP) (input: household-debt, GDP)
#
#     housing price, rent: https://data.gov.hk/en-data/dataset/hk-rvd-tsinfo_rvd-property-market-statistics
#     GDP per capita: https://data.worldbank.org/indicator/NY.GDP.PCAP.CD?locations=HK
#     Household debt: https://www.imf.org/external/datamapper/HH_LS@GDD/USA/CHN/MEX/BRA/THA/IDN/PER/BGR%E3%80%82/HKG
#
#
# limitations:
# 1. multiple the df by 44.97 across the whole 20-year span
# 2.
#
# #calculate disposible income by minus inflation rate and cpi increase + rent
# #total income = indebtedness / percentage of GDP

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
# load the csv, drop na columns
df = pd.read_csv('HKPR.csv', skiprows=0)
df = df.set_index('Quarter')
df = df.drop(columns={'Rents (Hong Kong) - Remarks', 'Rents (Kowloon) - Remarks', 'Prices (Hong Kong) - Remarks', 'Prices (Kowloon) - Remarks', 'Rents (New Territories) - Remarks', 'Prices (New Territories) - Remarks'})

# %%
# multiple Hong Kong’s average house size of 484 sq ft (44.97sqrm): https://alifeshift.com/2018/01/16/hong-kong-house-sizes/
# df = df * (44.97)

# %%
#calculate price-to-rent ratio
df['Price-Rent Ratio(Hong Kong)'] = df['Prices (Hong Kong)']/ df['Rents (Hong Kong)']
df['Price-Rent Ratio(Kowloon)'] = df['Prices (Kowloon)']/ df['Rents (Kowloon)']
df['Price-Rent Ratio(New Territories)'] = df['Prices (New Territories)']/ df['Rents (New Territories)']
df
# Out:
#             Rents (Hong Kong)  Rents (Kowloon)  Rents (New Territories)  \
# Quarter
# 01-03/1999                785              832                      603
# 04-06/1999                772              843                      668
# 07-09/1999                784              938                      668
# 10-12/1999                752              930                      739
# 01-03/2000                790              947                      681
# ...                       ...              ...                      ...
# 10-12/2018               1511             1411                     1359
# 01-03/2019               1529             1442                     1356
# 04-06/2019               1679             1380                     1383
# 07-09/2019               1485             1409                     1345
# 10-12/2019               1383             1351                     1285
#
#             Prices (Hong Kong)  Prices (Kowloon)  Prices (New Territories)  \
# Quarter
# 01-03/1999              120296            170880                    118316
# 04-06/1999              137119            170794                    109663
# 07-09/1999              158919            183239                    108245
# 10-12/1999              113060            143140                    113535
# 01-03/2000              118601            140883                     85018
# ...                        ...               ...                       ...
# 10-12/2018              500357            358294                    345395
# 01-03/2019              580583            381240                    379316
# 04-06/2019              425536            380294                    329627
# 07-09/2019              513651            427000                    530362
# 10-12/2019              560678            382124                    364752
#
#             Price-Rent Ratio(Hong Kong)  Price-Rent Ratio(Kowloon)  \
# Quarter
# 01-03/1999                   153.243312                 205.384615
# 04-06/1999                   177.615285                 202.602610
# 07-09/1999                   202.702806                 195.350746
# 10-12/1999                   150.345745                 153.913978
# 01-03/2000                   150.127848                 148.767687
# ...                                 ...                        ...
# 10-12/2018                   331.142952                 253.929128
# 01-03/2019                   379.714192                 264.382802
# 04-06/2019                   253.446099                 275.575362
# 07-09/2019                   345.892929                 303.051810
# 10-12/2019                   405.407086                 282.845300
#
#             Price-Rent Ratio(New Territories)
# Quarter
# 01-03/1999                         196.212272
# 04-06/1999                         164.166168
# 07-09/1999                         162.043413
# 10-12/1999                         153.633288
# 01-03/2000                         124.842878
# ...                                       ...
# 10-12/2018                         254.153790
# 01-03/2019                         279.731563
# 04-06/2019                         238.342010
# 07-09/2019                         394.321190
# 10-12/2019                         283.853696
#
# [84 rows x 9 columns]

# %%
# read household debt, keep only 1999 to 2019
household_debt = pd.read_excel('HDEBT.xls')

#dropping years before 1999
year_drop = []
for year in range(1950, 1998):
    year_drop.append(year)   
household_debt = household_debt.drop(year_drop, axis=1).dropna()

#switch rows and columns, resetting index and renaming colunms
household_debt = household_debt.transpose()
household_debt.reset_index(level=0, inplace=True)
household_debt = household_debt.drop(index=[0,1])
household_debt.columns = ['Year', 'Household Debt (% of GDP)']
household_debt.reset_index(level=0, inplace=True)
household_debt = household_debt.drop('index', axis=1)
# household_debt = household_debt.set_index('Year')
household_debt
# Out:
#     Year Household Debt (% of GDP)
# 0   1999                   58.0448
# 1   2000                   57.9026
# 2   2001                   60.3021
# 3   2002                    60.513
# 4   2003                   59.9066
# 5   2004                   57.7243
# 6   2005                   54.9255
# 7   2006                   51.6746
# 8   2007                   51.0757
# 9   2008                   51.3209
# 10  2009                   55.4497
# 11  2010                   59.2298
# 12  2011                   59.0537
# 13  2012                   61.2614
# 14  2013                   62.6525
# 15  2014                   65.4758
# 16  2015                   67.0858
# 17  2016                   67.6297
# 18  2017                   70.5094
# 19  2018                   72.2105

# %%
#load csv, rearranging to match the style
GDP_Percap = pd.read_csv('GDPPCAP.csv', skiprows=4)

#transpose
GDP_Percap = GDP_Percap.loc[GDP_Percap['Country Name'] == 'Hong Kong SAR, China']
GDP_Percap = GDP_Percap.transpose()

#drop unwatned years
GDP_Percap.reset_index(level=0, inplace=True)
GDP_Percap = GDP_Percap.drop(index=range(2003-1960)).dropna()
GDP_Percap.columns = ['Year', 'GDP per capita']
GDP_Percap.reset_index(level=0, inplace=True)
GDP_Percap = GDP_Percap.drop('index', axis=1)
# GDP_Percap = GDP_Percap.set_index('Year')
GDP_Percap
# Out:
#     Year GDP per capita
# 0   1999        25091.7
# 1   2000        25756.7
# 2   2001        25230.2
# 3   2002        24665.9
# 4   2003          23977
# 5   2004        24928.1
# 6   2005        26649.8
# 7   2006        28224.2
# 8   2007          30594
# 9   2008        31515.7
# 10  2009        30697.3
# 11  2010          32550
# 12  2011        35142.5
# 13  2012        36730.9
# 14  2013        38403.8
# 15  2014        40315.3
# 16  2015        42431.9
# 17  2016        43734.2
# 18  2017        46225.8
# 19  2018        48675.6

# %%
# calculate net income (%)
# merge
# House Price-Income Ratio
# Real House Prices

# %%
merge_df = pd.merge(GDP_Percap, household_debt, left_index=True, right_index=True)
merge_df = merge_df.drop('Year_y', axis=1)
merge_df = merge_df.rename(columns={'Year_x': "Year"})

merge_df
# Out:
#     Year GDP per capita Household Debt (% of GDP)
# 0   1999        25091.7                   58.0448
# 1   2000        25756.7                   57.9026
# 2   2001        25230.2                   60.3021
# 3   2002        24665.9                    60.513
# 4   2003          23977                   59.9066
# 5   2004        24928.1                   57.7243
# 6   2005        26649.8                   54.9255
# 7   2006        28224.2                   51.6746
# 8   2007          30594                   51.0757
# 9   2008        31515.7                   51.3209
# 10  2009        30697.3                   55.4497
# 11  2010          32550                   59.2298
# 12  2011        35142.5                   59.0537
# 13  2012        36730.9                   61.2614
# 14  2013        38403.8                   62.6525
# 15  2014        40315.3                   65.4758
# 16  2015        42431.9                   67.0858
# 17  2016        43734.2                   67.6297
# 18  2017        46225.8                   70.5094
# 19  2018        48675.6                   72.2105

# %%
# mannually adding figures (cant download the file b/c paywalls)
# disposible income source:https://www.statista.com/statistics/755874/hong-kong-disposable-income-per-capita/
# yearly GDP source: https://countryeconomy.com/gdp/hong-kong
# CPI source: https://www.worlddata.info/asia/hong-kong/inflation-rates.php

disposible_income = np.array([2532.4, 2420.5, 2286.8, 2157.9, 2046.2])
gdp_list = np.array([[320.877, 309.359, 291.438, 275.673, 262.601]])
income_modifier = (disposible_income/ (gdp_list * 7.75)).mean()

merge_df['Disposible income'] = merge_df['GDP per capita'] * income_modifier
merge_df['Household Debt'] = merge_df['GDP per capita'] * (merge_df['Household Debt (% of GDP)'] / 100)
merge_df['CPI %'] = np.array([-4.01, -3.69, -1.66, -2.98, -2.67, -0.27, 0.83, 2.01, 2.03, 4.30, 0.58, 2.31, 5.28, 4.06, 4.32, 4.44, 3.00, 2.41, 1.48, 2.41])


# covert to HKD
merge_df['GDP per capita'] = (merge_df['GDP per capita'] * 7.75)
merge_df['Disposible income'] = (merge_df['Disposible income'] * 7.75)
merge_df['Household Debt'] = (merge_df['Household Debt'] * 7.75)

merge_df
# Out:
#     Year GDP per capita Household Debt (% of GDP) Disposible income  \
# 0   1999         194460                   58.0448            196632
# 1   2000         199614                   57.9026            201844
# 2   2001         195534                   60.3021            197718
# 3   2002         191161                    60.513            193296
# 4   2003         185822                   59.9066            187897
# 5   2004         193193                   57.7243            195350
# 6   2005         206536                   54.9255            208842
# 7   2006         218738                   51.6746            221181
# 8   2007         237104                   51.0757            239752
# 9   2008         244246                   51.3209            246974
# 10  2009         237904                   55.4497            240561
# 11  2010         252262                   59.2298            255080
# 12  2011         272354                   59.0537            275396
# 13  2012         284664                   61.2614            287844
# 14  2013         297629                   62.6525            300953
# 15  2014         312443                   65.4758            315933
# 16  2015         328847                   67.0858            332520
# 17  2016         338940                   67.6297            342726
# 18  2017         358250                   70.5094            362251
# 19  2018         377236                   72.2105            381449
#
#    Household Debt  CPI %
# 0          112874  -4.01
# 1          115582  -3.69
# 2          117911  -1.66
# 3          115677  -2.98
# 4          111320  -2.67
# 5          111519  -0.27
# 6          113441   0.83
# 7          113032   2.01
# 8          121102   2.03
# 9          125350   4.30
# 10         131917   0.58
# 11         149414   2.31
# 12         160835   5.28
# 13         174389   4.06
# 14         186472   4.32
# 15         204575   4.44
# 16         220610   3.00
# 17         229225   2.41
# 18         252600   1.48
# 19         272404   2.41

# %%
# go back to the quarterly chart, convert them into yearly

# %%
df.reset_index()
df = df.T
df = df.drop(columns={'01-03/2019','04-06/2019','07-09/2019','10-12/2019'}, axis=1)
# df

# %%
# add new years as columns
quarters_length = int(len(df.columns) / 4)
quarters_length
for idx in range(1, quarters_length + 1):
    df[str(idx)] = df[ [df.columns[((idx * 4) - 4)], df.columns[((idx * 4) - 3)], df.columns[((idx * 4) - 2)], df.columns[((idx * 4) - 1)]] ].mean(axis=1)
# df

# %%
# Drop irrelevant months, rename quarters
drop_start = df.columns.get_loc('01-03/1999')
drop_end = df.columns.get_loc('1')
drop_list = []
for jdx in range(drop_start, drop_end):
    drop_list.append(df.columns[jdx])
df = df.drop(drop_list, axis=1)
# df

# %%
# rename columns
year_list = []
for year in range(1999, 2019):
    year_list.append(year)
df.columns = year_list
# df

# %%
# transpose, rename columns
df = df.T
df = df.reset_index()
df = df.rename(columns={'index': 'Year'})
df
# Out:
#     Year  Rents (Hong Kong)  Rents (Kowloon)  Rents (New Territories)  \
# 0   1999             773.25           885.75                   669.50
# 1   2000             797.50           972.00                   745.25
# 2   2001             860.50           938.50                   683.50
# 3   2002             791.00           868.25                   647.00
# 4   2003             755.75           837.00                   664.50
# 5   2004             842.25           900.50                   712.00
# 6   2005             937.75           980.50                   767.75
# 7   2006             997.50          1006.50                   786.50
# 8   2007            1061.00          1027.00                   814.75
# 9   2008            1184.25          1110.75                   896.50
# 10  2009            1077.75          1080.25                   855.50
# 11  2010            1238.25          1176.25                   941.00
# 12  2011            1292.00          1246.00                  1033.50
# 13  2012            1468.75          1446.00                  1155.50
# 14  2013            1546.25          1479.75                  1168.75
# 15  2014            1616.25          1540.75                  1240.25
# 16  2015            1605.25          1515.25                  1278.50
# 17  2016            1501.25          1340.25                  1295.25
# 18  2017            1517.25          1400.00                  1321.25
# 19  2018            1531.75          1430.75                  1345.75
#
#     Prices (Hong Kong)  Prices (Kowloon)  Prices (New Territories)  \
# 0            132348.50         167013.25                 112439.75
# 1            122205.00         152432.00                  88737.75
# 2            110088.75         125181.25                  92706.25
# 3            122810.50         120307.75                 108133.75
# 4            118487.75         121983.25                  96003.00
# 5            167461.00         205780.00                 110045.25
# 6            179598.00         216635.50                 142236.00
# 7            163297.25         182813.50                 111647.50
# 8            235236.00         209095.50                 141123.50
# 9            222488.25         229903.75                 141316.75
# 10           281322.50         247357.25                 147044.50
# 11           301202.00         290863.00                 194923.75
# 12           422455.00         361488.00                 253753.00
# 13           508166.75         445406.25                 300392.75
# 14           517800.75         426425.25                 350245.25
# 15           464074.25         425249.00                 388811.75
# 16           560553.00         397018.50                 366015.00
# 17           483877.00         404203.25                 394368.75
# 18           529298.75         375363.50                 401638.75
# 19           491353.00         429981.25                 399671.75
#
#     Price-Rent Ratio(Hong Kong)  Price-Rent Ratio(Kowloon)  \
# 0                    170.976787                 189.312987
# 1                    153.160432                 156.589320
# 2                    128.389716                 134.298424
# 3                    155.307163                 139.758896
# 4                    157.131105                 144.741174
# 5                    199.369940                 228.723756
# 6                    192.495696                 226.231355
# 7                    164.228362                 183.003466
# 8                    221.338049                 204.810367
# 9                    188.007895                 208.351787
# 10                   260.525438                 230.714928
# 11                   243.700197                 247.109887
# 12                   327.549925                 291.626232
# 13                   348.860695                 308.593746
# 14                   334.716503                 288.842231
# 15                   290.356479                 276.141776
# 16                   349.794510                 261.632079
# 17                   321.461599                 301.381981
# 18                   349.079602                 268.778463
# 19                   321.552634                 300.181886
#
#     Price-Rent Ratio(New Territories)
# 0                          169.013785
# 1                          119.909613
# 2                          135.432536
# 3                          166.923483
# 4                          145.199740
# 5                          154.247736
# 6                          184.999399
# 7                          142.291802
# 8                          173.015773
# 9                          157.994941
# 10                         171.472899
# 11                         207.340356
# 12                         245.600784
# 13                         259.545503
# 14                         300.739430
# 15                         314.868847
# 16                         286.326044
# 17                         305.017145
# 18                         304.029535
# 19                         297.081765

# %%
# merge
final_df = pd.merge(df, merge_df, left_index=True, right_index=True)
final_df = final_df.drop('Year_y', axis=1)
final_df = final_df.rename(columns={'Year_x': 'Year'})
final_df = final_df.set_index('Year')
# final_df

# %%
# calculate Price-Income Ratio, 44.96 is the average size of all houses in HK, source: https://alifeshift.com/2018/01/16/hong-kong-house-sizes/
final_df['Price-Income Ratio(Hong Kong)'] = (final_df['Prices (Hong Kong)'] * 44.96)/ final_df['Disposible income']
final_df['Price-Income Ratio(Kowloon)'] = (final_df['Prices (Kowloon)'] * 44.96)/ final_df['Disposible income']
final_df['Price-Income Ratio(New Territories)'] = (final_df['Prices (New Territories)'] * 44.96)/ final_df['Disposible income']

final_df
# Out:
#       Rents (Hong Kong)  Rents (Kowloon)  Rents (New Territories)  \
# Year
# 1999             773.25           885.75                   669.50
# 2000             797.50           972.00                   745.25
# 2001             860.50           938.50                   683.50
# 2002             791.00           868.25                   647.00
# 2003             755.75           837.00                   664.50
# 2004             842.25           900.50                   712.00
# 2005             937.75           980.50                   767.75
# 2006             997.50          1006.50                   786.50
# 2007            1061.00          1027.00                   814.75
# 2008            1184.25          1110.75                   896.50
# 2009            1077.75          1080.25                   855.50
# 2010            1238.25          1176.25                   941.00
# 2011            1292.00          1246.00                  1033.50
# 2012            1468.75          1446.00                  1155.50
# 2013            1546.25          1479.75                  1168.75
# 2014            1616.25          1540.75                  1240.25
# 2015            1605.25          1515.25                  1278.50
# 2016            1501.25          1340.25                  1295.25
# 2017            1517.25          1400.00                  1321.25
# 2018            1531.75          1430.75                  1345.75
#
#       Prices (Hong Kong)  Prices (Kowloon)  Prices (New Territories)  \
# Year
# 1999           132348.50         167013.25                 112439.75
# 2000           122205.00         152432.00                  88737.75
# 2001           110088.75         125181.25                  92706.25
# 2002           122810.50         120307.75                 108133.75
# 2003           118487.75         121983.25                  96003.00
# 2004           167461.00         205780.00                 110045.25
# 2005           179598.00         216635.50                 142236.00
# 2006           163297.25         182813.50                 111647.50
# 2007           235236.00         209095.50                 141123.50
# 2008           222488.25         229903.75                 141316.75
# 2009           281322.50         247357.25                 147044.50
# 2010           301202.00         290863.00                 194923.75
# 2011           422455.00         361488.00                 253753.00
# 2012           508166.75         445406.25                 300392.75
# 2013           517800.75         426425.25                 350245.25
# 2014           464074.25         425249.00                 388811.75
# 2015           560553.00         397018.50                 366015.00
# 2016           483877.00         404203.25                 394368.75
# 2017           529298.75         375363.50                 401638.75
# 2018           491353.00         429981.25                 399671.75
#
#       Price-Rent Ratio(Hong Kong)  Price-Rent Ratio(Kowloon)  \
# Year
# 1999                   170.976787                 189.312987
# 2000                   153.160432                 156.589320
# 2001                   128.389716                 134.298424
# 2002                   155.307163                 139.758896
# 2003                   157.131105                 144.741174
# 2004                   199.369940                 228.723756
# 2005                   192.495696                 226.231355
# 2006                   164.228362                 183.003466
# 2007                   221.338049                 204.810367
# 2008                   188.007895                 208.351787
# 2009                   260.525438                 230.714928
# 2010                   243.700197                 247.109887
# 2011                   327.549925                 291.626232
# 2012                   348.860695                 308.593746
# 2013                   334.716503                 288.842231
# 2014                   290.356479                 276.141776
# 2015                   349.794510                 261.632079
# 2016                   321.461599                 301.381981
# 2017                   349.079602                 268.778463
# 2018                   321.552634                 300.181886
#
#       Price-Rent Ratio(New Territories) GDP per capita  \
# Year
# 1999                         169.013785         194460
# 2000                         119.909613         199614
# 2001                         135.432536         195534
# 2002                         166.923483         191161
# 2003                         145.199740         185822
# 2004                         154.247736         193193
# 2005                         184.999399         206536
# 2006                         142.291802         218738
# 2007                         173.015773         237104
# 2008                         157.994941         244246
# 2009                         171.472899         237904
# 2010                         207.340356         252262
# 2011                         245.600784         272354
# 2012                         259.545503         284664
# 2013                         300.739430         297629
# 2014                         314.868847         312443
# 2015                         286.326044         328847
# 2016                         305.017145         338940
# 2017                         304.029535         358250
# 2018                         297.081765         377236
#
#      Household Debt (% of GDP) Disposible income Household Debt  CPI %  \
# Year
# 1999                   58.0448            196632         112874  -4.01
# 2000                   57.9026            201844         115582  -3.69
# 2001                   60.3021            197718         117911  -1.66
# 2002                    60.513            193296         115677  -2.98
# 2003                   59.9066            187897         111320  -2.67
# 2004                   57.7243            195350         111519  -0.27
# 2005                   54.9255            208842         113441   0.83
# 2006                   51.6746            221181         113032   2.01
# 2007                   51.0757            239752         121102   2.03
# 2008                   51.3209            246974         125350   4.30
# 2009                   55.4497            240561         131917   0.58
# 2010                   59.2298            255080         149414   2.31
# 2011                   59.0537            275396         160835   5.28
# 2012                   61.2614            287844         174389   4.06
# 2013                   62.6525            300953         186472   4.32
# 2014                   65.4758            315933         204575   4.44
# 2015                   67.0858            332520         220610   3.00
# 2016                   67.6297            342726         229225   2.41
# 2017                   70.5094            362251         252600   1.48
# 2018                   72.2105            381449         272404   2.41
#
#      Price-Income Ratio(Hong Kong) Price-Income Ratio(Kowloon)  \
# Year
# 1999                       30.2615                     38.1876
# 2000                       27.2208                     33.9537
# 2001                       25.0336                     28.4655
# 2002                       28.5654                     27.9832
# 2003                       28.3517                     29.1881
# 2004                       38.5412                     47.3604
# 2005                       38.6642                     46.6378
# 2006                       33.1939                      37.161
# 2007                       44.1132                     39.2111
# 2008                       40.5025                     41.8524
# 2009                       52.5781                     46.2301
# 2010                       53.0894                     51.2671
# 2011                       68.9682                      59.015
# 2012                       79.3736                     69.5707
# 2013                       77.3553                     63.7045
# 2014                       66.0418                     60.5166
# 2015                       75.7924                     53.6809
# 2016                       63.4767                     53.0248
# 2017                       65.6928                     46.5874
# 2018                        57.914                     50.6803
#
#      Price-Income Ratio(New Territories)
# Year
# 1999                             25.7094
# 2000                             19.7661
# 2001                             21.0809
# 2002                             25.1516
# 2003                             22.9716
# 2004                              25.327
# 2005                             30.6209
# 2006                             22.6949
# 2007                             26.4645
# 2008                             25.7258
# 2009                             27.4821
# 2010                              34.357
# 2011                             41.4266
# 2012                             46.9201
# 2013                             52.3238
# 2014                             55.3313
# 2015                             49.4889
# 2016                             51.7347
# 2017                             49.8485
# 2018                             47.1078

# %%
final_df = final_df.drop(columns={'Rents (Hong Kong)', 'Rents (Kowloon)', 'Rents (New Territories)',
       'Prices (Hong Kong)', 'Prices (Kowloon)', 'Prices (New Territories)', 'GDP per capita', 'Disposible income', 'Household Debt'})
final_df
# Out:
#       Price-Rent Ratio(Hong Kong)  Price-Rent Ratio(Kowloon)  \
# Year
# 1999                   170.976787                 189.312987
# 2000                   153.160432                 156.589320
# 2001                   128.389716                 134.298424
# 2002                   155.307163                 139.758896
# 2003                   157.131105                 144.741174
# 2004                   199.369940                 228.723756
# 2005                   192.495696                 226.231355
# 2006                   164.228362                 183.003466
# 2007                   221.338049                 204.810367
# 2008                   188.007895                 208.351787
# 2009                   260.525438                 230.714928
# 2010                   243.700197                 247.109887
# 2011                   327.549925                 291.626232
# 2012                   348.860695                 308.593746
# 2013                   334.716503                 288.842231
# 2014                   290.356479                 276.141776
# 2015                   349.794510                 261.632079
# 2016                   321.461599                 301.381981
# 2017                   349.079602                 268.778463
# 2018                   321.552634                 300.181886
#
#       Price-Rent Ratio(New Territories) Household Debt (% of GDP)  CPI %  \
# Year
# 1999                         169.013785                   58.0448  -4.01
# 2000                         119.909613                   57.9026  -3.69
# 2001                         135.432536                   60.3021  -1.66
# 2002                         166.923483                    60.513  -2.98
# 2003                         145.199740                   59.9066  -2.67
# 2004                         154.247736                   57.7243  -0.27
# 2005                         184.999399                   54.9255   0.83
# 2006                         142.291802                   51.6746   2.01
# 2007                         173.015773                   51.0757   2.03
# 2008                         157.994941                   51.3209   4.30
# 2009                         171.472899                   55.4497   0.58
# 2010                         207.340356                   59.2298   2.31
# 2011                         245.600784                   59.0537   5.28
# 2012                         259.545503                   61.2614   4.06
# 2013                         300.739430                   62.6525   4.32
# 2014                         314.868847                   65.4758   4.44
# 2015                         286.326044                   67.0858   3.00
# 2016                         305.017145                   67.6297   2.41
# 2017                         304.029535                   70.5094   1.48
# 2018                         297.081765                   72.2105   2.41
#
#      Price-Income Ratio(Hong Kong) Price-Income Ratio(Kowloon)  \
# Year
# 1999                       30.2615                     38.1876
# 2000                       27.2208                     33.9537
# 2001                       25.0336                     28.4655
# 2002                       28.5654                     27.9832
# 2003                       28.3517                     29.1881
# 2004                       38.5412                     47.3604
# 2005                       38.6642                     46.6378
# 2006                       33.1939                      37.161
# 2007                       44.1132                     39.2111
# 2008                       40.5025                     41.8524
# 2009                       52.5781                     46.2301
# 2010                       53.0894                     51.2671
# 2011                       68.9682                      59.015
# 2012                       79.3736                     69.5707
# 2013                       77.3553                     63.7045
# 2014                       66.0418                     60.5166
# 2015                       75.7924                     53.6809
# 2016                       63.4767                     53.0248
# 2017                       65.6928                     46.5874
# 2018                        57.914                     50.6803
#
#      Price-Income Ratio(New Territories)
# Year
# 1999                             25.7094
# 2000                             19.7661
# 2001                             21.0809
# 2002                             25.1516
# 2003                             22.9716
# 2004                              25.327
# 2005                             30.6209
# 2006                             22.6949
# 2007                             26.4645
# 2008                             25.7258
# 2009                             27.4821
# 2010                              34.357
# 2011                             41.4266
# 2012                             46.9201
# 2013                             52.3238
# 2014                             55.3313
# 2015                             49.4889
# 2016                             51.7347
# 2017                             49.8485
# 2018                             47.1078

# %%
#benchmarks, sources: https://www.deptofnumbers.com/rent/us/; https://www.google.com/search?q=usa+average+house+price+in+2007&oq=usa+average+house+price+in+2007&aqs=chrome..69i57j33.4431j0j7&sourceid=chrome&ie=UTF-8
USA_Price_Rent = 201900/899

# source: https://data.worldbank.org/indicator/NY.GDP.PCAP.CD
USA_Price_Income = 201900/48061.54

# source: https://www.imf.org/external/datamapper/HH_LS@GDD/USA/CHN/MEX/BRA/THA/IDN/PER/BGR%E3%80%82/HKG
USA_Household_Debt = 51.075689

# source: https://www.in2013dollars.com/us/inflation/2007
USA_CPI = 2.85


(USA_Price_Rent, USA_Price_Income, USA_Household_Debt)
# Out:
# (224.58286985539488, 4.200864142097819, 51.075689)

# %%
# fig, ax = plt.subplots()
x_val = np.array(final_df.index)
y_ptr_hk = np.array(final_df['Price-Rent Ratio(Hong Kong)'])
y_ptr_kl = np.array(final_df['Price-Rent Ratio(Kowloon)'])
y_ptr_nt = np.array(final_df['Price-Rent Ratio(New Territories)'])
y_pir_hk = np.array(final_df['Price-Income Ratio(Hong Kong)'])
y_pir_kl = np.array(final_df['Price-Income Ratio(Kowloon)'])
y_pir_nt = np.array(final_df['Price-Income Ratio(New Territories)'])
y_hdr = np.array(final_df['Household Debt (% of GDP)'])
y_cpi = np.array(final_df['CPI %'])

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x_val, y_ptr_hk, '-', x_val, y_ptr_kl, '-', x_val, y_ptr_nt, '-')
plt.legend(['Hong Kong', 'Kowloon', 'New Territories'])

plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', right=False, left=False, labelleft=True)
for pos in ['right','top','bottom','left']:
    plt.gca().spines[pos].set_visible(False)
    
plt.title('Price-to-Rent index')

# plot constant line & bar chart
plt.axhline(y=USA_Price_Rent, color='k', linestyle='-')
# Out:
# <img src="data:image/png;base64,..." width="1042">

# %%
plt.subplot(2,2,2)
plt.bar(x_val, y_hdr)
plt.xticks(x_val[::3])
plt.title('Household Debt (% of GDP)')

plt.axhline(y=USA_Household_Debt, color='r', linestyle='-')

plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True

# %%
plt.subplot(2,2,3)
plt.scatter(x_val, y_cpi, color='g')
plt.legend(['% of CPI'])
plt.xticks(x_val[::3])

plt.axhline(y=USA_CPI, color='gray', linestyle='-')

plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False

# %%
plt.subplot(2,2,4)
plt.title('Price-to-Income Index')
plt.plot(x_val, y_pir_hk, '-,', x_val, y_pir_kl, '-,', x_val, y_pir_nt, '-')
plt.legend(['Hong Kong', 'Kowloon', 'New Territories'])
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', right=False, left=False, labelleft=False)
for pos in ['right','top','bottom','left']:
    plt.gca().spines[pos].set_visible(False)

plt.axhline(y=USA_Price_Income, color='k', linestyle='-')
